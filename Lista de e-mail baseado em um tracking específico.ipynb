# %%
import numpy as np
import pandas as pd
import io

# %%
from pandas import ExcelWriter
from pandas import ExcelFile
from io import StringIO

# %%
df = pd.read_csv("C:\\Users\\ericat\\Downloads\\BLiP - Users Events (2).csv", header = 2, usecols = [0,1,2,3,4])

# %%
df.head()
# Out:
#                    DataEvento                    Category             Action  \
# 0  16/04/2019 00:01:45 -03:00         Encerrou - conteudo     Olá boa noite.
# 1  16/04/2019 00:01:45 -03:00  Input handler - 1 - origem           Encerrou
# 2  16/04/2019 00:01:45 -03:00           Input handler - 1           Exibicao
# 3  16/04/2019 00:01:45 -03:00  Input handler - 2 - origem  Input handler - 1
# 4  16/04/2019 00:01:45 -03:00           Input handler - 2           Exibicao
#
#                      UserName                          UserID
# 0  VALESKA APARECIDA DA SILVA  5512981809413@wa.gw.msging.net
# 1  VALESKA APARECIDA DA SILVA  5512981809413@wa.gw.msging.net
# 2  VALESKA APARECIDA DA SILVA  5512981809413@wa.gw.msging.net
# 3  VALESKA APARECIDA DA SILVA  5512981809413@wa.gw.msging.net
# 4  VALESKA APARECIDA DA SILVA  5512981809413@wa.gw.msging.net

# %%
spec_tracking = df[df['Category'] == "Consulta dados realizada"]

# %%
spec_tracking
# Out:
#                         DataEvento                  Category    Action  \
# 189     16/04/2019 00:21:55 -03:00  Consulta dados realizada  Exibicao
# 2655    16/04/2019 03:57:32 -03:00  Consulta dados realizada  Exibicao
# 3733    16/04/2019 04:55:44 -03:00  Consulta dados realizada  Exibicao
# 4922    16/04/2019 06:14:34 -03:00  Consulta dados realizada  Exibicao
# 5904    16/04/2019 07:05:58 -03:00  Consulta dados realizada  Exibicao
# 6719    16/04/2019 07:35:47 -03:00  Consulta dados realizada  Exibicao
# 7260    16/04/2019 07:42:06 -03:00  Consulta dados realizada  Exibicao
# 7491    16/04/2019 07:48:01 -03:00  Consulta dados realizada  Exibicao
# 7731    16/04/2019 07:50:04 -03:00  Consulta dados realizada  Exibicao
# 13674   16/04/2019 08:54:06 -03:00  Consulta dados realizada  Exibicao
# 14029   16/04/2019 08:55:17 -03:00  Consulta dados realizada  Exibicao
# 15481   16/04/2019 09:10:45 -03:00  Consulta dados realizada  Exibicao
# ...

# %%
users = spec_tracking["UserID"]

# %%
users
# Out:
# 189       5521969637105@wa.gw.msging.net
# 2655      5511988582115@wa.gw.msging.net
# 3733      5521964849837@wa.gw.msging.net
# 4922      5521986028441@wa.gw.msging.net
# 5904      5521987283819@wa.gw.msging.net
# 6719      5511961234016@wa.gw.msging.net
# 7260      5511947632210@wa.gw.msging.net
# 7491      5511958122690@wa.gw.msging.net
# 7731      5511947560631@wa.gw.msging.net
# 13674     5511940877260@wa.gw.msging.net
# 14029     5511940877260@wa.gw.msging.net
# 15481     5511969407315@wa.gw.msging.net
# 16498     5511930608438@wa.gw.msging.net
# 18149     5521964847952@wa.gw.msging.net
# 19146     5511968285615@wa.gw.msging.net
# 19160     5513997711236@wa.gw.msging.net
# 22319     5511981641780@wa.gw.msging.net
# 22918     5511991533307@wa.gw.msging.net
# 23693     5513974176929@wa.gw.msging.net
# 23895     5513974176929@wa.gw.msging.net
# 24179     5519989454840@wa.gw.msging.net
# 27495     5521964374090@wa.gw.msging.net
# 27789     5511998945594@wa.gw.msging.net
# ...

# %%
count = users.shape[0]

# %%
print(count)
# Out:
# 964

# %%
users.to_csv("C:\\Users\\ericat\\Downloads\\listaconsumo2.csv", sep=';', index=False)
